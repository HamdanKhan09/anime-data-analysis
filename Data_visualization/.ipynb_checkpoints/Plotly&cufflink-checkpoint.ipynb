# %%
# !pip install plotly==5.17.0
# !pip install cufflinks
# !pip install "numpy<2.0"
# Out:
# Requirement already satisfied: plotly==5.17.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from plotly==5.17.0) (9.0.0)
# Requirement already satisfied: packaging in c:\users\hamdan khan\anaconda3\lib\site-packages (from plotly==5.17.0) (24.2)
# Requirement already satisfied: cufflinks in c:\users\hamdan khan\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (2.1.3)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (2.2.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (5.17.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (72.1.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (8.30.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from cufflinks) (8.1.5)
# Requirement already satisfied: decorator in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.19.1)
# Requirement already satisfied: stack-data in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.14.3)
# Requirement already satisfied: colorama in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\hamdan khan\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.13)
# Requirement already satisfied: jupyterlab_widgets~=3.0.12 in c:\users\hamdan khan\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\hamdan khan\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hamdan khan\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hamdan khan\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hamdan khan\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hamdan khan\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (9.0.0)
# Requirement already satisfied: packaging in c:\users\hamdan khan\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (24.2)
# Requirement already satisfied: executing in c:\users\hamdan khan\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hamdan khan\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\hamdan khan\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)

# %%
import seaborn as sn
import pandas as pd
import cufflinks as cf
from plotly.offline import iplot

# %%
tips = sns.load_dataset('tips')

# %%
tips['total_bill'].iplot(kind='hist')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 tips['total_bill'].iplot(kind='hist')
#
# File ~\anaconda3\Lib\site-packages\cufflinks\plotlytools.py:930, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     928 	__['y']=__['x']
#     929 	del __['x']
# --> 930 __ = Histogram(__)
#     931 if bins:
#     932 	if type(bins) in (tuple,list):
#
# File ~\anaconda3\Lib\site-packages\plotly\graph_objs\_histogram.py:3069, in Histogram.__init__(self, arg, alignmentgroup, autobinx, autobiny, bingroup, cliponaxis, constraintext, cumulative, customdata, customdatasrc, error_x, error_y, histfunc, histnorm, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, nbinsx, nbinsy, offsetgroup, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textsrc, texttemplate, uid, uirevision, unselected, visible, x, xaxis, xbins, xcalendar, xhoverformat, xsrc, y, yaxis, ybins, ycalendar, yhoverformat, ysrc, **kwargs)
#    3067 _v = marker if marker is not None else _v
#    3068 if _v is not None:
# -> 3069     self["marker"] = _v
#    3070 _v = arg.pop("meta", None)
#    3071 _v = meta if meta is not None else _v
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4868, in BasePlotlyType.__setitem__(self, prop, value)
#    4866 # ### Handle compound property ###
#    4867 if isinstance(validator, CompoundValidator):
# -> 4868     self._set_compound_prop(prop, value)
#    4870 # ### Handle compound array property ###
#    4871 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5279, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5276 # Import value
#    5277 # ------------
#    5278 validator = self._get_validator(prop)
# -> 5279 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5281 # Save deep copies of current and new states
#    5282 # ------------------------------------------
#    5283 curr_val = self._compound_props.get(prop, None)
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:2475, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2472     v = self.data_class()
#    2474 elif isinstance(v, dict):
# -> 2475     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2477 elif isinstance(v, self.data_class):
#    2478     # Copy object
#    2479     v = self.data_class(v)
#
# File ~\anaconda3\Lib\site-packages\plotly\graph_objs\histogram\_marker.py:1159, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#    1157 _v = color if color is not None else _v
#    1158 if _v is not None:
# -> 1159     self["color"] = _v
#    1160 _v = arg.pop("coloraxis", None)
#    1161 _v = coloraxis if coloraxis is not None else _v
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:4876, in BasePlotlyType.__setitem__(self, prop, value)
#    4872         self._set_array_prop(prop, value)
#    4874     # ### Handle simple property ###
#    4875     else:
# -> 4876         self._set_prop(prop, value)
#    4877 else:
#    4878     # Make sure properties dict is initialized
#    4879     self._init_props()
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5220, in BasePlotlyType._set_prop(self, prop, val)
#    5218         return
#    5219     else:
# -> 5220         raise err
#    5222 # val is None
#    5223 # -----------
#    5224 if val is None:
#    5225     # Check if we should send null update
#
# File ~\anaconda3\Lib\site-packages\plotly\basedatatypes.py:5215, in BasePlotlyType._set_prop(self, prop, val)
#    5212 validator = self._get_validator(prop)
#    5214 try:
# -> 5215     val = validator.validate_coerce(val)
#    5216 except ValueError as err:
#    5217     if self._skip_invalid:
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File ~\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:287, in BaseValidator.raise_invalid_val(self, v, inds)
#     284             for i in inds:
#     285                 name += "[" + str(i) + "]"
# --> 287         raise ValueError(
#     288             """
#     289     Invalid value of type {typ} received for the '{name}' property of {pname}
#     290         Received value: {v}
#     291
#     292 {valid_clr_desc}""".format(
#     293                 name=name,
#     294                 pname=self.parent_name,
#     295                 typ=type_str(v),
#     296                 v=repr(v),
#     297                 valid_clr_desc=self.description(),
#     298             )
#     299         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of histogram.marker
#         Received value: 'rgba(255, 153, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color:
#             aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen
#       - A number that will be interpreted as a color
#         according to histogram.marker.colorscale
#       - A list or array of any of the above
