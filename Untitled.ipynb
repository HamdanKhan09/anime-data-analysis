# %%
import numpy as np

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])

# %%
b= np.sum(s,axis = 1)
for i in b:
    if i !=45:
        print("suduko is not valid")
        break
else:
        print("valid for rows")
# Out:
# valid for rows

# %%
c= np.sum(s,axis = 1)
for i in c:
    if i !=45:
        print("suduko is not valid")
        break
else:
        print("valid for column")
# Out:
# valid for column

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
data[:,2][data[:,2] < 75] = 0
print(data)
# Out:
# [[18 85 78]
#  [19 92 88]
#  [17 76 95]
#  [18 65  0]
#  [20 90 85]]
